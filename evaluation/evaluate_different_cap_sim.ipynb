# %% [markdown]
# ## Import lib

# %%
import csv
import matplotlib.pyplot as plt
from numpy import loadtxt

# %% [markdown]
# ### Import all files

# %% [markdown]
# 7 - 5 - 7

# %%
unbalance_triangle_reward_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress_diff_cap_7_5/tue_abc_one_service/trace_config_100_sim_duration_pop1_pop2/sfc_requirement_one_service/2021-06-22_12-45-45_seed9834/monitor.csv'

# %%
unbalance_trained_400_triangle_drop_request = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress_diff_cap_7_5/tue_abc_one_service/trace_config_100_sim_duration_pop1_pop2/sfc_requirement_one_service/2021-06-22_12-45-45_seed9834/test-2021-06-22_12-45-45_seed9834/run_flows.csv'
unbalance_trained_400_triangle_total_request = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress_diff_cap_7_5/tue_abc_one_service/trace_config_100_sim_duration_pop1_pop2/sfc_requirement_one_service/2021-06-22_12-45-45_seed9834/test-2021-06-22_12-45-45_seed9834/run_flows.csv'
unbalance_balance_triangle_drop_request = '/home/dat/git_folder_edge_4/realVNF/baseline-algorithms/results/tue_network_triangle_15_cap_pop1_pop2_ingress_diff_cap_7_5/tue_abc_one_service/trace_config_100_sim_duration_pop1_pop2/2021-07-01_17-52-21_seed5567-balance/run_flows.csv'
unbalance_balance_triangle_total_request = '/home/dat/git_folder_edge_4/realVNF/baseline-algorithms/results/tue_network_triangle_15_cap_pop1_pop2_ingress_diff_cap_7_5/tue_abc_one_service/trace_config_100_sim_duration_pop1_pop2/2021-07-01_17-52-21_seed5567-balance/run_flows.csv'
unbalance_random_triangle_drop_request = '/home/dat/git_folder_edge_4/realVNF/baseline-algorithms/results/tue_network_triangle_15_cap_pop1_pop2_ingress_diff_cap_7_5/tue_abc_one_service/trace_config_100_sim_duration_pop1_pop2/2021-07-01_17-55-04_seed7077-random/run_flows.csv'
unbalance_random_triangle_total_request = '/home/dat/git_folder_edge_4/realVNF/baseline-algorithms/results/tue_network_triangle_15_cap_pop1_pop2_ingress_diff_cap_7_5/tue_abc_one_service/trace_config_100_sim_duration_pop1_pop2/2021-07-01_17-55-04_seed7077-random/run_flows.csv'
unbalance_shortest_triangle_drop_request = '/home/dat/git_folder_edge_4/realVNF/baseline-algorithms/results/tue_network_triangle_15_cap_pop1_pop2_ingress_diff_cap_7_5/tue_abc_one_service/trace_config_100_sim_duration_pop1_pop2/2021-07-01_17-54-04_seed769-shortest_path/run_flows.csv'
unbalance_shortest_triangle_total_request = '/home/dat/git_folder_edge_4/realVNF/baseline-algorithms/results/tue_network_triangle_15_cap_pop1_pop2_ingress_diff_cap_7_5/tue_abc_one_service/trace_config_100_sim_duration_pop1_pop2/2021-07-01_17-54-04_seed769-shortest_path/run_flows.csv'

# %% [markdown]
# 7 - 7 - 7

# %%
balance_triangle_reward_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/tue_abc_one_service/trace_config_100_sim_duration_pop1_pop2/sfc_requirement_one_service/2021-06-21_21-20-39_seed9834/monitor.csv'

# %%
balance_trained_400_triangle_drop_request = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/tue_abc_one_service/trace_config_100_sim_duration_pop1_pop2/sfc_requirement_one_service/2021-06-21_21-20-39_seed9834/test-2021-06-21_21-20-39_seed9834/run_flows.csv'
balance_trained_400_triangle_total_request = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/tue_abc_one_service/trace_config_100_sim_duration_pop1_pop2/sfc_requirement_one_service/2021-06-21_21-20-39_seed9834/test-2021-06-21_21-20-39_seed9834/run_flows.csv'
balance_balance_triangle_drop_request = '/home/dat/git_folder_edge_4/realVNF/baseline-algorithms/results/tue_network_triangle_15_cap_pop1_pop2_ingress/tue_abc_one_service/trace_config_100_sim_duration_pop1_pop2/2021-07-07_18-31-11_seed461-balance/run_flows.csv'
balance_balance_triangle_total_request = '/home/dat/git_folder_edge_4/realVNF/baseline-algorithms/results/tue_network_triangle_15_cap_pop1_pop2_ingress/tue_abc_one_service/trace_config_100_sim_duration_pop1_pop2/2021-07-07_18-31-11_seed461-balance/run_flows.csv'
balance_random_triangle_drop_request = '/home/dat/git_folder_edge_4/realVNF/baseline-algorithms/results/tue_network_triangle_15_cap_pop1_pop2_ingress/tue_abc_one_service/trace_config_100_sim_duration_pop1_pop2/2021-07-07_18-29-09_seed848-random/run_flows.csv'
balance_random_triangle_total_request = '/home/dat/git_folder_edge_4/realVNF/baseline-algorithms/results/tue_network_triangle_15_cap_pop1_pop2_ingress/tue_abc_one_service/trace_config_100_sim_duration_pop1_pop2/2021-07-07_18-29-09_seed848-random/run_flows.csv'
balance_shortest_triangle_drop_request = '/home/dat/git_folder_edge_4/realVNF/baseline-algorithms/results/tue_network_triangle_15_cap_pop1_pop2_ingress/tue_abc_one_service/trace_config_100_sim_duration_pop1_pop2/2021-07-07_18-28-19_seed468-shortestPath/run_flows.csv'
balance_shortest_triangle_total_request = '/home/dat/git_folder_edge_4/realVNF/baseline-algorithms/results/tue_network_triangle_15_cap_pop1_pop2_ingress/tue_abc_one_service/trace_config_100_sim_duration_pop1_pop2/2021-07-07_18-28-19_seed468-shortestPath/run_flows.csv'

# %% [markdown]
# ### Functions for processing

# %% [markdown]
# To read to list

# %%
def read_csv_to_list(file_path, index_start_reading, colum_number):
    return_array = list()
    with open(file_path, newline='') as csvfile:
        spamreader = csv.reader(csvfile, delimiter=',', quotechar='|')
        for index, row in enumerate(spamreader):
            if index >= index_start_reading:
                return_array.append(float(row[colum_number]))
    return return_array

# %% [markdown]
# Calculate drop/succ rate

# %%
def calculate_drop_succ_rate(drop_arr, succ_arr):
    rate_arr = [drop_arr[i]/(drop_arr[i] + succ_arr[i]) for i in range(len(drop_arr))]
    return rate_arr

# %%
def calculate_drop_total_rate(drop_arr, total_arr):
    rate_arr = [drop_arr[i]/total_arr[i] for i in range(len(drop_arr))]
    return rate_arr

# %% [markdown]
# Filter for abnormal value

# %%
def filter_abnormal_values(array, value):
    return [i for i in array if i < value]

# %% [markdown]
# Ingress normalize

# %%
def ingress_traffic_calculation(ingress_arr):
    return [i*500 for i in ingress_arr]

# %% [markdown]
# ### Read files to variables

# %%
algos = ['trained_400', 'random', 'shortest', 'balance']
topology = "triangle"

# %%
unbalance_drop_request = list()
unbalance_total_request = list()
unbalance_drop_succ_rate = list()

unbalance_reward_sim = read_csv_to_list(eval(f"unbalance_{topology}_reward_file_path"), 2, 0)
for ind, algo in enumerate(algos):
    unbalance_drop_request.append(read_csv_to_list(eval(f"unbalance_{algo}_{topology}_drop_request"), 1, 3))
    unbalance_total_request.append(read_csv_to_list(eval(f"unbalance_{algo}_{topology}_total_request"), 1, 4))
    unbalance_drop_succ_rate.append(calculate_drop_total_rate(eval(f"unbalance_drop_request[{ind}]"), eval(f"unbalance_total_request[{ind}]")))

# %%
balance_drop_request = list()
balance_total_request = list()
balance_drop_succ_rate = list()

balance_reward_sim = read_csv_to_list(eval(f"balance_{topology}_reward_file_path"), 2, 0)
for ind, algo in enumerate(algos):
    balance_drop_request.append(read_csv_to_list(eval(f"balance_{algo}_{topology}_drop_request"), 1, 3))
    balance_total_request.append(read_csv_to_list(eval(f"balance_{algo}_{topology}_total_request"), 1, 4))
    balance_drop_succ_rate.append(calculate_drop_total_rate(eval(f"balance_drop_request[{ind}]"), eval(f"balance_total_request[{ind}]")))

# %% [markdown]
# ### Draw latency graph through time after each case

# %%
plt.plot(unbalance_reward_sim, label="hexagon")
plt.title("Reward of RL models in different topology")
plt.xlabel("Trained episodes")
plt.ylabel("Reward")
plt.legend()
plt.show()

# %%
plt.plot(balance_reward_sim, label="hexagon")
plt.title("Reward of RL models in different topology")
plt.xlabel("Trained episodes")
plt.ylabel("Reward")
plt.legend()
plt.show()

# %% [markdown]
# ### Algoprithm compare

# %%
x_range = [i * 15 for i in range(len(unbalance_drop_succ_rate[0]))]

for index, algo in enumerate(algos):
    if algo == 'random':
        continue
    if algo == 'trained_400':
        plt.plot(x_range, unbalance_drop_succ_rate[index], label=f'RL model')
    else:
        plt.plot(x_range, unbalance_drop_succ_rate[index], label=f'{algo}')
    
plt.title("Drop request rate in unbalance topology")
plt.xlabel("Time (minute)")
plt.ylabel("Drop request rate")
plt.legend()
plt.show()

# %%
x_range = [i * 15 for i in range(len(balance_drop_succ_rate[0]))]

for index, algo in enumerate(algos):
    if algo == 'random':
        continue
    if algo == 'trained_400':
        plt.plot(x_range, balance_drop_succ_rate[index], label=f'RL model')
    else:
        plt.plot(x_range, balance_drop_succ_rate[index], label=f'{algo}')

plt.title("Drop request rate in balance topology")
plt.xlabel("Time (minute)")
plt.ylabel("Drop request rate")
plt.legend()
plt.show()
