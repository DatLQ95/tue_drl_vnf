# %% [markdown]
# ## Import lib

# %%
import csv
import matplotlib.pyplot as plt
from numpy import loadtxt

# %% [markdown]
# ### Import all files

# %% [markdown]
# #### balance file 100-100-100

# %%
reward_sim_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-21_21-20-39_seed9834/monitor.csv'

# %% [markdown]
# ##### 100-100-100

# %%
trained_200_run_reward_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-21_21-20-39_seed9834/test-2021-06-22_17-18-17_seed3000/0/rewards.csv'
trained_200_drop_request_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-21_21-20-39_seed9834/test-2021-06-22_17-18-17_seed3000/0/drop_request.csv'
trained_200_ingress_traffic_file_path ='/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-21_21-20-39_seed9834/test-2021-06-22_17-18-17_seed3000/0/ingress_traffic.csv'
trained_200_latency_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-21_21-20-39_seed9834/test-2021-06-22_17-18-17_seed3000/0/latency.csv'
trained_200_succ_request_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-21_21-20-39_seed9834/test-2021-06-22_17-18-17_seed3000/0/succ_request.csv'
trained_200_runtime_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-21_21-20-39_seed9834/test-2021-06-22_17-18-17_seed3000/0/runtimes.csv'

trained_0_run_reward_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-22_19-45-13_seed1574-test-no-training/0/rewards.csv'
trained_0_drop_request_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-22_19-45-13_seed1574-test-no-training/0/drop_request.csv'
trained_0_ingress_traffic_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-22_19-45-13_seed1574-test-no-training/0/ingress_traffic.csv'
trained_0_latency_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-22_19-45-13_seed1574-test-no-training/0/latency.csv'
trained_0_succ_request_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-22_19-45-13_seed1574-test-no-training/0/succ_request.csv'
trained_0_runtime_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-22_19-45-13_seed1574-test-no-training/0/runtimes.csv'

# trained_5_run_reward_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-21_21-20-39_seed9834_5_episodes/test-2021-06-22_21-12-24_seed8492/run_reward.csv'
# trained_5_drop_request_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-21_21-20-39_seed9834_5_episodes/test-2021-06-22_21-12-24_seed8492/0/drop_request.csv'
# trained_5_ingress_traffic_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-21_21-20-39_seed9834_5_episodes/test-2021-06-22_21-12-24_seed8492/0/ingress_traffic.csv'
# trained_5_latency_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-21_21-20-39_seed9834_5_episodes/test-2021-06-22_21-12-24_seed8492/0/latency.csv'
# trained_5_succ_request_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-21_21-20-39_seed9834_5_episodes/test-2021-06-22_21-12-24_seed8492/0/succ_request.csv'
# trained_5_runtime_file_path = 

trained_10_run_reward_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-21_21-20-39_seed9834_10_episodes/test-2021-06-22_22-19-00_seed4207/0/rewards.csv'
trained_10_drop_request_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-21_21-20-39_seed9834_10_episodes/test-2021-06-22_22-19-00_seed4207/0/drop_request.csv'
trained_10_ingress_traffic_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-21_21-20-39_seed9834_10_episodes/test-2021-06-22_22-19-00_seed4207/0/ingress_traffic.csv'
trained_10_latency_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-21_21-20-39_seed9834_10_episodes/test-2021-06-22_22-19-00_seed4207/0/latency.csv'
trained_10_succ_request_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-21_21-20-39_seed9834_10_episodes/test-2021-06-22_22-19-00_seed4207/0/succ_request.csv'
trained_10_runtime_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-21_21-20-39_seed9834_10_episodes/test-2021-06-22_22-19-00_seed4207/0/runtimes.csv'

trained_20_run_reward_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-21_21-20-39_seed9834_20_episodes/test-2021-06-22_23-25-06_seed3775/0/rewards.csv'
trained_20_drop_request_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-21_21-20-39_seed9834_20_episodes/test-2021-06-22_23-25-06_seed3775/0/drop_request.csv'
trained_20_ingress_traffic_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-21_21-20-39_seed9834_20_episodes/test-2021-06-22_23-25-06_seed3775/0/ingress_traffic.csv'
trained_20_latency_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-21_21-20-39_seed9834_20_episodes/test-2021-06-22_23-25-06_seed3775/0/latency.csv'
trained_20_succ_request_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-21_21-20-39_seed9834_20_episodes/test-2021-06-22_23-25-06_seed3775/0/succ_request.csv'
trained_20_runtime_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-21_21-20-39_seed9834_20_episodes/test-2021-06-22_23-25-06_seed3775/0/runtimes.csv'

trained_30_run_reward_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-21_21-20-39_seed9834_30_episodes/test-2021-06-23_00-31-46_seed1863/0/rewards.csv'
trained_30_drop_request_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-21_21-20-39_seed9834_30_episodes/test-2021-06-23_00-31-46_seed1863/0/drop_request.csv'
trained_30_ingress_traffic_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-21_21-20-39_seed9834_30_episodes/test-2021-06-23_00-31-46_seed1863/0/ingress_traffic.csv'
trained_30_latency_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-21_21-20-39_seed9834_30_episodes/test-2021-06-23_00-31-46_seed1863/0/latency.csv'
trained_30_succ_request_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-21_21-20-39_seed9834_30_episodes/test-2021-06-23_00-31-46_seed1863/0/succ_request.csv'
trained_30_runtime_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-21_21-20-39_seed9834_30_episodes/test-2021-06-23_00-31-46_seed1863/0/runtimes.csv'

trained_40_run_reward_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-21_21-20-39_seed9834_40_episodes/test-2021-06-23_09-07-26_seed9775/0/rewards.csv'
trained_40_drop_request_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-21_21-20-39_seed9834_40_episodes/test-2021-06-23_09-07-26_seed9775/0/drop_request.csv'
trained_40_ingress_traffic_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-21_21-20-39_seed9834_40_episodes/test-2021-06-23_09-07-26_seed9775/0/ingress_traffic.csv'
trained_40_latency_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-21_21-20-39_seed9834_40_episodes/test-2021-06-23_09-07-26_seed9775/0/latency.csv'
trained_40_succ_request_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-21_21-20-39_seed9834_40_episodes/test-2021-06-23_09-07-26_seed9775/0/succ_request.csv'
trained_40_runtime_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-21_21-20-39_seed9834_40_episodes/test-2021-06-23_09-07-26_seed9775/0/runtimes.csv'

trained_160_run_reward_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-21_21-20-39_seed9834_160_episodes/test-2021-06-23_10-20-36_seed5235/0/rewards.csv'
trained_160_drop_request_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-21_21-20-39_seed9834_160_episodes/test-2021-06-23_10-20-36_seed5235/0/drop_request.csv'
trained_160_ingress_traffic_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-21_21-20-39_seed9834_160_episodes/test-2021-06-23_10-20-36_seed5235/0/ingress_traffic.csv'
trained_160_latency_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-21_21-20-39_seed9834_160_episodes/test-2021-06-23_10-20-36_seed5235/0/latency.csv'
trained_160_succ_request_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-21_21-20-39_seed9834_160_episodes/test-2021-06-23_10-20-36_seed5235/0/succ_request.csv'
trained_160_runtime_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-21_21-20-39_seed9834_160_episodes/test-2021-06-23_10-20-36_seed5235/0/runtimes.csv'

# %% [markdown]
# #### 200-200-200

# %%
trained_200_run_reward_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-21_21-20-39_seed9834/test-2021-06-24_00-15-18_seed7331/0/rewards.csv'
trained_200_drop_request_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-21_21-20-39_seed9834/test-2021-06-24_00-15-18_seed7331/0/drop_request.csv'
trained_200_ingress_traffic_file_path ='/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-21_21-20-39_seed9834/test-2021-06-24_00-15-18_seed7331/0/ingress_traffic.csv'
trained_200_latency_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-21_21-20-39_seed9834/test-2021-06-24_00-15-18_seed7331/0/latency.csv'
trained_200_succ_request_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-21_21-20-39_seed9834/test-2021-06-24_00-15-18_seed7331/0/succ_request.csv'
trained_200_runtime_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-21_21-20-39_seed9834/test-2021-06-24_00-15-18_seed7331/0/runtimes.csv'

# trained_0_run_reward_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-22_19-45-13_seed1574-test-no-training/0/rewards.csv'
# trained_0_drop_request_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-22_19-45-13_seed1574-test-no-training/0/drop_request.csv'
# trained_0_ingress_traffic_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-22_19-45-13_seed1574-test-no-training/0/ingress_traffic.csv'
# trained_0_latency_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-22_19-45-13_seed1574-test-no-training/0/latency.csv'
# trained_0_succ_request_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-22_19-45-13_seed1574-test-no-training/0/succ_request.csv'
# trained_0_runtime_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-22_19-45-13_seed1574-test-no-training/0/runtimes.csv'

# trained_5_run_reward_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-21_21-20-39_seed9834_5_episodes/test-2021-06-22_21-12-24_seed8492/run_reward.csv'
# trained_5_drop_request_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-21_21-20-39_seed9834_5_episodes/test-2021-06-22_21-12-24_seed8492/0/drop_request.csv'
# trained_5_ingress_traffic_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-21_21-20-39_seed9834_5_episodes/test-2021-06-22_21-12-24_seed8492/0/ingress_traffic.csv'
# trained_5_latency_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-21_21-20-39_seed9834_5_episodes/test-2021-06-22_21-12-24_seed8492/0/latency.csv'
# trained_5_succ_request_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-21_21-20-39_seed9834_5_episodes/test-2021-06-22_21-12-24_seed8492/0/succ_request.csv'
# trained_5_runtime_file_path = 

trained_10_run_reward_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-21_21-20-39_seed9834_10_episodes/test-2021-06-24_02-01-27_seed8361/0/rewards.csv'
trained_10_drop_request_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-21_21-20-39_seed9834_10_episodes/test-2021-06-24_02-01-27_seed8361/0/drop_request.csv'
trained_10_ingress_traffic_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-21_21-20-39_seed9834_10_episodes/test-2021-06-24_02-01-27_seed8361/0/ingress_traffic.csv'
trained_10_latency_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-21_21-20-39_seed9834_10_episodes/test-2021-06-24_02-01-27_seed8361/0/latency.csv'
trained_10_succ_request_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-21_21-20-39_seed9834_10_episodes/test-2021-06-24_02-01-27_seed8361/0/succ_request.csv'
trained_10_runtime_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-21_21-20-39_seed9834_10_episodes/test-2021-06-24_02-01-27_seed8361/0/runtimes.csv'

trained_20_run_reward_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-21_21-20-39_seed9834_20_episodes/test-2021-06-24_05-26-51_seed1653/0/rewards.csv'
trained_20_drop_request_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-21_21-20-39_seed9834_20_episodes/test-2021-06-24_05-26-51_seed1653/0/drop_request.csv'
trained_20_ingress_traffic_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-21_21-20-39_seed9834_20_episodes/test-2021-06-24_05-26-51_seed1653/0/ingress_traffic.csv'
trained_20_latency_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-21_21-20-39_seed9834_20_episodes/test-2021-06-24_05-26-51_seed1653/0/latency.csv'
trained_20_succ_request_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-21_21-20-39_seed9834_20_episodes/test-2021-06-24_05-26-51_seed1653/0/succ_request.csv'
trained_20_runtime_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-21_21-20-39_seed9834_20_episodes/test-2021-06-24_05-26-51_seed1653/0/runtimes.csv'

trained_30_run_reward_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-21_21-20-39_seed9834_30_episodes/test-2021-06-24_08-21-42_seed4511/0/rewards.csv'
trained_30_drop_request_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-21_21-20-39_seed9834_30_episodes/test-2021-06-24_08-21-42_seed4511/0/drop_request.csv'
trained_30_ingress_traffic_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-21_21-20-39_seed9834_30_episodes/test-2021-06-24_08-21-42_seed4511/0/ingress_traffic.csv'
trained_30_latency_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-21_21-20-39_seed9834_30_episodes/test-2021-06-24_08-21-42_seed4511/0/latency.csv'
trained_30_succ_request_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-21_21-20-39_seed9834_30_episodes/test-2021-06-24_08-21-42_seed4511/0/succ_request.csv'
trained_30_runtime_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-21_21-20-39_seed9834_30_episodes/test-2021-06-24_08-21-42_seed4511/0/runtimes.csv'

trained_40_run_reward_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-21_21-20-39_seed9834_40_episodes/test-2021-06-24_09-43-01_seed3950/0/rewards.csv'
trained_40_drop_request_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-21_21-20-39_seed9834_40_episodes/test-2021-06-24_09-43-01_seed3950/0/drop_request.csv'
trained_40_ingress_traffic_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-21_21-20-39_seed9834_40_episodes/test-2021-06-24_09-43-01_seed3950/0/ingress_traffic.csv'
trained_40_latency_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-21_21-20-39_seed9834_40_episodes/test-2021-06-24_09-43-01_seed3950/0/latency.csv'
trained_40_succ_request_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-21_21-20-39_seed9834_40_episodes/test-2021-06-24_09-43-01_seed3950/0/succ_request.csv'
trained_40_runtime_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-21_21-20-39_seed9834_40_episodes/test-2021-06-24_09-43-01_seed3950/0/runtimes.csv'

# trained_160_run_reward_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-21_21-20-39_seed9834_160_episodes/test-2021-06-23_10-20-36_seed5235/0/rewards.csv'
# trained_160_drop_request_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-21_21-20-39_seed9834_160_episodes/test-2021-06-23_10-20-36_seed5235/0/drop_request.csv'
# trained_160_ingress_traffic_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-21_21-20-39_seed9834_160_episodes/test-2021-06-23_10-20-36_seed5235/0/ingress_traffic.csv'
# trained_160_latency_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-21_21-20-39_seed9834_160_episodes/test-2021-06-23_10-20-36_seed5235/0/latency.csv'
# trained_160_succ_request_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-21_21-20-39_seed9834_160_episodes/test-2021-06-23_10-20-36_seed5235/0/succ_request.csv'
# trained_160_runtime_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-21_21-20-39_seed9834_160_episodes/test-2021-06-23_10-20-36_seed5235/0/runtimes.csv'

# %% [markdown]
# #### 200-100-200

# %%
reward_sim_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress_diff_cap_7_5/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-22_12-45-45_seed9834/monitor.csv'

# %%
trained_200_run_reward_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress_diff_cap_7_5/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-22_12-45-45_seed9834/test-2021-06-24_11-06-44_seed5852/0/rewards.csv'
trained_200_drop_request_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress_diff_cap_7_5/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-22_12-45-45_seed9834/test-2021-06-24_11-06-44_seed5852/0/drop_request.csv'
trained_200_ingress_traffic_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress_diff_cap_7_5/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-22_12-45-45_seed9834/test-2021-06-24_11-06-44_seed5852/0/ingress_traffic.csv'
trained_200_latency_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress_diff_cap_7_5/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-22_12-45-45_seed9834/test-2021-06-24_11-06-44_seed5852/0/latency.csv'
trained_200_succ_request_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress_diff_cap_7_5/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-22_12-45-45_seed9834/test-2021-06-24_11-06-44_seed5852/0/succ_request.csv'
trained_200_runtime_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress_diff_cap_7_5/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-22_12-45-45_seed9834/test-2021-06-24_11-06-44_seed5852/0/runtimes.csv'

trained_0_run_reward_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress_diff_cap_7_5/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-23_16-27-37_seed3895/0/rewards.csv'
trained_0_drop_request_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress_diff_cap_7_5/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-23_16-27-37_seed3895/0/drop_request.csv'
trained_0_ingress_traffic_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress_diff_cap_7_5/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-23_16-27-37_seed3895/0/ingress_traffic.csv'
trained_0_latency_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress_diff_cap_7_5/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-23_16-27-37_seed3895/0/latency.csv'
trained_0_succ_request_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress_diff_cap_7_5/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-23_16-27-37_seed3895/0/succ_request.csv'
trained_0_runtime_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress_diff_cap_7_5/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-23_16-27-37_seed3895/0/runtimes.csv'

trained_5_run_reward_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress_diff_cap_7_5/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-22_12-45-45_seed9834_5_episodes/test-2021-06-24_12-24-20_seed4188/0/rewards.csv'
trained_5_drop_request_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress_diff_cap_7_5/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-22_12-45-45_seed9834_5_episodes/test-2021-06-24_12-24-20_seed4188/0/drop_request.csv'
trained_5_ingress_traffic_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress_diff_cap_7_5/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-22_12-45-45_seed9834_5_episodes/test-2021-06-24_12-24-20_seed4188/0/ingress_traffic.csv'
trained_5_latency_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress_diff_cap_7_5/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-22_12-45-45_seed9834_5_episodes/test-2021-06-24_12-24-20_seed4188/0/latency.csv'
trained_5_succ_request_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress_diff_cap_7_5/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-22_12-45-45_seed9834_5_episodes/test-2021-06-24_12-24-20_seed4188/0/succ_request.csv'
trained_5_runtime_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress_diff_cap_7_5/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-22_12-45-45_seed9834_5_episodes/test-2021-06-24_12-24-20_seed4188/0/runtimes.csv'

trained_10_run_reward_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress_diff_cap_7_5/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-22_12-45-45_seed9834_10_episodes/test-2021-06-23_20-18-34_seed4949/0/rewards.csv'
trained_10_drop_request_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress_diff_cap_7_5/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-22_12-45-45_seed9834_10_episodes/test-2021-06-23_20-18-34_seed4949/0/drop_request.csv'
trained_10_ingress_traffic_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress_diff_cap_7_5/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-22_12-45-45_seed9834_10_episodes/test-2021-06-23_20-18-34_seed4949/0/ingress_traffic.csv'
trained_10_latency_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress_diff_cap_7_5/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-22_12-45-45_seed9834_10_episodes/test-2021-06-23_20-18-34_seed4949/0/latency.csv'
trained_10_succ_request_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress_diff_cap_7_5/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-22_12-45-45_seed9834_10_episodes/test-2021-06-23_20-18-34_seed4949/0/succ_request.csv'
trained_10_runtime_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress_diff_cap_7_5/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-22_12-45-45_seed9834_10_episodes/test-2021-06-23_20-18-34_seed4949/0/runtimes.csv'

trained_20_run_reward_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress_diff_cap_7_5/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-22_12-45-45_seed9834_20_episodes/test-2021-06-23_21-28-38_seed8184/0/rewards.csv'
trained_20_drop_request_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress_diff_cap_7_5/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-22_12-45-45_seed9834_20_episodes/test-2021-06-23_21-28-38_seed8184/0/drop_request.csv'
trained_20_ingress_traffic_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress_diff_cap_7_5/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-22_12-45-45_seed9834_20_episodes/test-2021-06-23_21-28-38_seed8184/0/ingress_traffic.csv'
trained_20_latency_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress_diff_cap_7_5/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-22_12-45-45_seed9834_20_episodes/test-2021-06-23_21-28-38_seed8184/0/latency.csv'
trained_20_succ_request_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress_diff_cap_7_5/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-22_12-45-45_seed9834_20_episodes/test-2021-06-23_21-28-38_seed8184/0/succ_request.csv'
trained_20_runtime_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress_diff_cap_7_5/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-22_12-45-45_seed9834_20_episodes/test-2021-06-23_21-28-38_seed8184/0/runtimes.csv'

trained_50_run_reward_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress_diff_cap_7_5/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-22_12-45-45_seed9834_50_episodes/test-2021-06-23_22-38-06_seed9002/0/rewards.csv'
trained_50_drop_request_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress_diff_cap_7_5/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-22_12-45-45_seed9834_50_episodes/test-2021-06-23_22-38-06_seed9002/0/drop_request.csv'
trained_50_ingress_traffic_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress_diff_cap_7_5/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-22_12-45-45_seed9834_50_episodes/test-2021-06-23_22-38-06_seed9002/0/ingress_traffic.csv'
trained_50_latency_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress_diff_cap_7_5/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-22_12-45-45_seed9834_50_episodes/test-2021-06-23_22-38-06_seed9002/0/latency.csv'
trained_50_succ_request_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress_diff_cap_7_5/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-22_12-45-45_seed9834_50_episodes/test-2021-06-23_22-38-06_seed9002/0/succ_request.csv'
trained_50_runtime_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress_diff_cap_7_5/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-22_12-45-45_seed9834_50_episodes/test-2021-06-23_22-38-06_seed9002/0/runtimes.csv'

# %%
random_run_reward_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/test_random/0/rewards.csv'
random_drop_request_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/test_random/0/drop_request.csv'
random_ingress_traffic_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/test_random/0/ingress_traffic.csv'
random_latency_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/test_random/0/latency.csv'
random_succ_request_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/test_random/0/succ_request.csv'

balance_run_reward_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/test_balance/0/rewards.csv'
balance_drop_request_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/test_balance/0/drop_request.csv'
balance_ingress_traffic_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/test_balance/0/ingress_traffic.csv'
balance_latency_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/test_balance/0/latency.csv'
balance_succ_request_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/test_balance/0/succ_request.csv'

shortest_run_reward_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/test_shortest_path/0/rewards.csv'
shortest_drop_request_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/test_shortest_path/0/drop_request.csv'
shortest_ingress_traffic_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/test_shortest_path/0/ingress_traffic.csv'
shortest_latency_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/test_shortest_path/0/latency.csv'
shortest_succ_request_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/test_shortest_path/0/succ_request.csv'

trained_200_run_reward_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress_diff_cap_7_5/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-22_12-45-45_seed9834/test-2021-06-24_11-06-44_seed5852/0/rewards.csv'
trained_200_drop_request_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress_diff_cap_7_5/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-22_12-45-45_seed9834/test-2021-06-24_11-06-44_seed5852/0/drop_request.csv'
trained_200_ingress_traffic_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress_diff_cap_7_5/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-22_12-45-45_seed9834/test-2021-06-24_11-06-44_seed5852/0/ingress_traffic.csv'
trained_200_latency_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress_diff_cap_7_5/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-22_12-45-45_seed9834/test-2021-06-24_11-06-44_seed5852/0/latency.csv'
trained_200_succ_request_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress_diff_cap_7_5/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-22_12-45-45_seed9834/test-2021-06-24_11-06-44_seed5852/0/succ_request.csv'
trained_200_runtime_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress_diff_cap_7_5/metro_network_services/trace_config_100_sim_duration_pop1_pop2/metro_network_service_requirement/metro_network_ingress_distribution/2021-06-22_12-45-45_seed9834/test-2021-06-24_11-06-44_seed5852/0/runtimes.csv'

# %% [markdown]
# ### Functions for processing

# %% [markdown]
# To read to list

# %%
def read_csv_to_list(file_path, index_start_reading, colum_number):
    return_array = list()
    with open(file_path, newline='') as csvfile:
        spamreader = csv.reader(csvfile, delimiter=',', quotechar='|')
        for index, row in enumerate(spamreader):
            if index >= index_start_reading:
                return_array.append(float(row[colum_number]))
    return return_array

# %% [markdown]
# Calculate drop/succ rate

# %%
def calculate_drop_succ_rate(drop_arr, succ_arr):
    rate_arr = [drop_arr[i]/(drop_arr[i] + succ_arr[i]) for i in range(len(drop_arr))]
    return rate_arr

# %% [markdown]
# Filter for abnormal value

# %%
def filter_abnormal_values(array, value):
    return [i for i in array if i < value]

# %% [markdown]
# Ingress normalize

# %%
def ingress_traffic_calculation(ingress_arr):
    return [i*500 for i in ingress_arr]

# %% [markdown]
# ### Read files to variables

# %%
reward_sim = read_csv_to_list(reward_sim_file_path, 2, 0)

# %%
run_reward = list()
drop_request = list()
norm_ingress_traffic = list()
latency = list()
succ_request = list()
drop_succ_rate = list()
runtime = list()
agent_time = list()
runtime_filtered = list()
agent_time_filtered = list()
ingress_traffic = list()

# number_test = [10, 20, 30, 40, 160, 200]
# number_test = [5, 10, 20, 50, 200]
# number_test = [10, 20, 30, 40, 200]
# reward_sim = read_csv_to_list(reward_sim_file_path, 2, 0)
# for ind, episodes in enumerate(number_test):
#     run_reward.append(read_csv_to_list(eval(f"trained_{episodes}_run_reward_file_path"), 1, 2))
#     drop_request.append(read_csv_to_list(eval(f"trained_{episodes}_drop_request_file_path"), 1, 2))
#     norm_ingress_traffic.append(read_csv_to_list(eval(f"trained_{episodes}_ingress_traffic_file_path"), 2, 3))
#     latency.append(read_csv_to_list(eval(f"trained_{episodes}_latency_file_path"), 1, 2))
#     succ_request.append(read_csv_to_list(eval(f"trained_{episodes}_succ_request_file_path"), 1, 2))
#     drop_succ_rate.append(calculate_drop_succ_rate(eval(f"drop_request[{ind}]"), eval(f"succ_request[{ind}]")))
#     runtime.append(read_csv_to_list(eval(f"trained_{episodes}_runtime_file_path"), 1, 1))
#     agent_time.append(read_csv_to_list(eval(f"trained_{episodes}_runtime_file_path"), 1, 2))
#     ingress_traffic.append(ingress_traffic_calculation(eval(f"norm_ingress_traffic[{ind}]")))
#     runtime_filtered.append(runtime_filtered(eval(f"runtime[{ind}]"), 45)
#     agent_time_filtered.append(agent_time)

algos = ['trained_200', 'random', 'shortest', 'balance']
for ind, algo in enumerate(algos):
    run_reward.append(read_csv_to_list(eval(f"{algo}_run_reward_file_path"), 1, 2))
    drop_request.append(read_csv_to_list(eval(f"{algo}_drop_request_file_path"), 1, 2))
    norm_ingress_traffic.append(read_csv_to_list(eval(f"{algo}_ingress_traffic_file_path"), 2, 3))
    latency.append(read_csv_to_list(eval(f"{algo}_latency_file_path"), 1, 2))
    succ_request.append(read_csv_to_list(eval(f"{algo}_succ_request_file_path"), 1, 2))
    drop_succ_rate.append(calculate_drop_succ_rate(eval(f"drop_request[{ind}]"), eval(f"succ_request[{ind}]")))
#     runtime.append(read_csv_to_list(eval(f"trained_{episodes}_runtime_file_path"), 1, 1))
#     agent_time.append(read_csv_to_list(eval(f"trained_{episodes}_runtime_file_path"), 1, 2))
    ingress_traffic.append(ingress_traffic_calculation(eval(f"norm_ingress_traffic[{ind}]")))

# %% [markdown]
# ### Draw latency graph through time after each case

# %%
x_range = [i * 15 for i in range(len(run_reward[0]))]

for index, episode in enumerate(number_test):
    plt.plot(x_range, run_reward[index], label=f'Train {episode}')

plt.title("Reward in a episode")
plt.xlabel("Time (minute)")
plt.ylabel("Step Reward")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-cffb562e686d> in <module>
#       1 x_range = [i * 15 for i in range(len(run_reward[0]))]
#       2
# ----> 3 for index, episode in enumerate(number_test):
#       4     plt.plot(x_range, run_reward[index], label=f'Train {episode}')
#       5
#
# NameError: name 'number_test' is not defined

# %%
x_range = [i * 15 for i in range(len(trained_200_drop_succ_rate))]

for index, episode in enumerate(number_test):
    plt.plot(x_range, drop_succ_rate[index], label=f'Train {episode}')


plt.title("Drop request rate in a episode")
plt.xlabel("Time (minute)")
plt.ylabel("Drop request rate")
plt.legend()
plt.show()

# %%
x_range = [i * 15 for i in range(len(trained_200_latency))]

for index, episode in enumerate(number_test):
    plt.plot(x_range, latency[index], label=f'Train {episode}')


plt.title("Latency in a episode")
plt.xlabel("Time (minute)")
plt.ylabel("Latency (ms)")
plt.legend()
plt.show()

# %%
x_range = [i * 15 for i in range(len(trained_200_ingress_traffic))]



for index, episode in enumerate(number_test):
    plt.plot(x_range, ingress_traffic[index], label=f'Train {episode}')

plt.title("Ingress traffic from a node in a episode")
plt.xlabel("Time (minute)")
plt.ylabel("Request rate (requests/s)")
plt.legend()
plt.show()

# %%
x_range = [i * 15 for i in range(len(trained_200_runtime))]

for index, episode in enumerate(number_test):
    plt.plot(x_range, runtime[index], label=f'Train {episode}')

plt.title("Run time for a step in a episode")
plt.xlabel("Time (minute)")
plt.ylabel("Run time (seconds)")
plt.legend()
plt.show()

# %%
x_range = [i * 15 for i in range(len(trained_200_runtime))]

for index, episode in enumerate(number_test):
    plt.plot(x_range, agent_time[index], label=f'Train {episode}')

plt.title("Run time in a episode")
plt.xlabel("Time (minute)")
plt.ylabel("RL agent time (seconds)")
plt.legend()

plt.show()

# %%
plt.plot(reward_sim, label="seed 9834")
plt.title("Reward of a RL model when training")
plt.xlabel("Trained episodes")
plt.ylabel("Reward")
plt.legend()
plt.show()

# %% [markdown]
# ### Algoprithm compare

# %%
x_range = [i * 15 for i in range(len(run_reward[0]))] 

for index, algo in enumerate(algos):
    plt.plot(x_range, run_reward[index], label=f'{algo}')

plt.title("Reward in a episode")
plt.xlabel("Time (minute)")
plt.ylabel("Step Reward")
plt.legend()
plt.show()

# %%
x_range = [i * 15 for i in range(len(drop_succ_rate[0]))]

for index, algo in enumerate(algos):
    plt.plot(x_range, drop_succ_rate[index], label=f'{algo}')

plt.title("Drop request rate in a episode")
plt.xlabel("Time (minute)")
plt.ylabel("Drop request rate")
plt.legend()
plt.show()

# %%
x_range = [i * 15 for i in range(len(latency[0]))]

for index, algo in enumerate(algos):
    plt.plot(x_range, latency[index], label=f'{algo}')


plt.title("Latency in a episode")
plt.xlabel("Time (minute)")
plt.ylabel("Latency (ms)")
plt.legend()
plt.show()

# %%
x_range = [i * 15 for i in range(len(ingress_traffic[0]))]

for index, algo in enumerate(algos):
    plt.plot(x_range, ingress_traffic[index], label=f'{algo}')

plt.title("Ingress traffic from a node in a episode")
plt.xlabel("Time (minute)")
plt.ylabel("Request rate (requests/s)")
plt.legend()
plt.show()
