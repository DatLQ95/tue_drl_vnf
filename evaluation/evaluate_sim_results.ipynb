# %% [markdown]
# ## Import lib

# %%
import csv
import matplotlib.pyplot as plt
from numpy import loadtxt

# %% [markdown]
# ### Import all files

# %% [markdown]
# triangle - 200 episodes

# %%
triangle_reward_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress_diff_cap_7_5/tue_abc_one_service/trace_config_100_sim_duration_pop1_pop2/sfc_requirement_one_service/2021-06-22_12-45-45_seed9834/monitor.csv'

# %%
trained_400_triangle_drop_request = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress_diff_cap_7_5/tue_abc_one_service/trace_config_100_sim_duration_pop1_pop2/sfc_requirement_one_service/2021-06-22_12-45-45_seed9834/test-2021-06-22_12-45-45_seed9834/run_flows.csv'
trained_400_triangle_total_request = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress_diff_cap_7_5/tue_abc_one_service/trace_config_100_sim_duration_pop1_pop2/sfc_requirement_one_service/2021-06-22_12-45-45_seed9834/test-2021-06-22_12-45-45_seed9834/run_flows.csv'
balance_triangle_drop_request = '/home/dat/git_folder_edge_4/realVNF/baseline-algorithms/results/tue_network_triangle_15_cap_pop1_pop2_ingress_diff_cap_7_5/tue_abc_one_service/trace_config_100_sim_duration_pop1_pop2/2021-07-01_17-52-21_seed5567-balance/run_flows.csv'
balance_triangle_total_request = '/home/dat/git_folder_edge_4/realVNF/baseline-algorithms/results/tue_network_triangle_15_cap_pop1_pop2_ingress_diff_cap_7_5/tue_abc_one_service/trace_config_100_sim_duration_pop1_pop2/2021-07-01_17-52-21_seed5567-balance/run_flows.csv'
random_triangle_drop_request = '/home/dat/git_folder_edge_4/realVNF/baseline-algorithms/results/tue_network_triangle_15_cap_pop1_pop2_ingress_diff_cap_7_5/tue_abc_one_service/trace_config_100_sim_duration_pop1_pop2/2021-07-01_17-55-04_seed7077-random/run_flows.csv'
random_triangle_total_request = '/home/dat/git_folder_edge_4/realVNF/baseline-algorithms/results/tue_network_triangle_15_cap_pop1_pop2_ingress_diff_cap_7_5/tue_abc_one_service/trace_config_100_sim_duration_pop1_pop2/2021-07-01_17-55-04_seed7077-random/run_flows.csv'
shortest_triangle_drop_request = '/home/dat/git_folder_edge_4/realVNF/baseline-algorithms/results/tue_network_triangle_15_cap_pop1_pop2_ingress_diff_cap_7_5/tue_abc_one_service/trace_config_100_sim_duration_pop1_pop2/2021-07-01_17-54-04_seed769-shortest_path/run_flows.csv'
shortest_triangle_total_request = '/home/dat/git_folder_edge_4/realVNF/baseline-algorithms/results/tue_network_triangle_15_cap_pop1_pop2_ingress_diff_cap_7_5/tue_abc_one_service/trace_config_100_sim_duration_pop1_pop2/2021-07-01_17-54-04_seed769-shortest_path/run_flows.csv'

# %%
hexagon_reward_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_hexagon_15_cap_pop1_pop2_ingress_diff_cap/tue_abc_one_service/trace_config_100_sim_duration_pop1_pop2/sfc_requirement_one_service/2021-06-27_20-22-47_seed4832/monitor.csv'

# %% [markdown]
# hexagon - 200 episodes

# %%
trained_200_hexagon_reward_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_hexagon_15_cap_pop1_pop2_ingress_diff_cap/tue_abc_one_service/trace_config_100_sim_duration_pop1_pop2/sfc_requirement_one_service/2021-06-27_20-22-47_seed4832/monitor.csv'
trained_400_hexagon_reward_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_hexagon_15_cap_pop1_pop2_ingress_diff_cap/tue_abc_one_service/trace_config_100_sim_duration_pop1_pop2/sfc_requirement_one_service/2021-06-30_13-07-56_seed4832/monitor.csv'
trained_400_triange_reward_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress_diff_cap_7_5/tue_abc_one_service/trace_config_100_sim_duration_pop1_pop2/sfc_requirement_one_service/2021-06-30_12-07-40_seed9834/monitor.csv'
trained_200_triange_reward_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_triangle_15_cap_pop1_pop2_ingress_diff_cap_7_5/tue_abc_one_service/trace_config_100_sim_duration_pop1_pop2/sfc_requirement_one_service/2021-06-22_12-45-45_seed9834/monitor.csv'
trained_400_octagon_reward_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_octagon_15_cap_pop1_pop2_ingress_diff_cap/tue_abc_one_service/trace_config_100_sim_duration_pop1_pop2/sfc_requirement_one_service/2021-06-30_18-39-53_seed9834/monitor.csv'

# %% [markdown]
# hexagon - 400 episodes

# %%
trained_400_hexagon_drop_request = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_hexagon_15_cap_pop1_pop2_ingress_diff_cap/tue_abc_one_service/trace_config_100_sim_duration_pop1_pop2/sfc_requirement_one_service/2021-06-30_13-07-56_seed4832/test-2021-06-30_13-07-56_seed4832/run_flows.csv'
trained_400_hexagon_total_request = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_hexagon_15_cap_pop1_pop2_ingress_diff_cap/tue_abc_one_service/trace_config_100_sim_duration_pop1_pop2/sfc_requirement_one_service/2021-06-30_13-07-56_seed4832/test-2021-06-30_13-07-56_seed4832/run_flows.csv'
trained_200_hexagon_drop_request = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_hexagon_15_cap_pop1_pop2_ingress_diff_cap/tue_abc_one_service/trace_config_100_sim_duration_pop1_pop2/sfc_requirement_one_service/2021-06-27_20-22-47_seed4832/test-2021-06-27_20-22-47_seed4832/run_flows.csv'
trained_200_hexagon_total_request = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_hexagon_15_cap_pop1_pop2_ingress_diff_cap/tue_abc_one_service/trace_config_100_sim_duration_pop1_pop2/sfc_requirement_one_service/2021-06-27_20-22-47_seed4832/test-2021-06-27_20-22-47_seed4832/run_flows.csv'
balance_hexagon_drop_request = '/home/dat/git_folder_edge_4/realVNF/baseline-algorithms/results/tue_network_hexagon_15_cap_pop1_pop2_ingress_diff_cap/tue_abc_one_service/trace_config_100_sim_duration_pop1_pop2/2021-06-30_12-52-13_seed7778-balance/run_flows.csv'
balance_hexagon_total_request = '/home/dat/git_folder_edge_4/realVNF/baseline-algorithms/results/tue_network_hexagon_15_cap_pop1_pop2_ingress_diff_cap/tue_abc_one_service/trace_config_100_sim_duration_pop1_pop2/2021-06-30_12-52-13_seed7778-balance/run_flows.csv'
random_hexagon_drop_request = '/home/dat/git_folder_edge_4/realVNF/baseline-algorithms/results/tue_network_hexagon_15_cap_pop1_pop2_ingress_diff_cap/tue_abc_one_service/trace_config_100_sim_duration_pop1_pop2/2021-06-30_12-55-15_seed9999-random/run_flows.csv'
random_hexagon_total_request = '/home/dat/git_folder_edge_4/realVNF/baseline-algorithms/results/tue_network_hexagon_15_cap_pop1_pop2_ingress_diff_cap/tue_abc_one_service/trace_config_100_sim_duration_pop1_pop2/2021-06-30_12-55-15_seed9999-random/run_flows.csv'
shortest_hexagon_drop_request = '/home/dat/git_folder_edge_4/realVNF/baseline-algorithms/results/tue_network_hexagon_15_cap_pop1_pop2_ingress_diff_cap/tue_abc_one_service/trace_config_100_sim_duration_pop1_pop2/2021-06-30_13-10-19_seed9185-shortest_path/run_flows.csv'
shortest_hexagon_total_request = '/home/dat/git_folder_edge_4/realVNF/baseline-algorithms/results/tue_network_hexagon_15_cap_pop1_pop2_ingress_diff_cap/tue_abc_one_service/trace_config_100_sim_duration_pop1_pop2/2021-06-30_13-10-19_seed9185-shortest_path/run_flows.csv'

# %% [markdown]
# octagon

# %%
octagon_reward_file_path = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_octagon_15_cap_pop1_pop2_ingress_diff_cap/tue_abc_one_service/trace_config_100_sim_duration_pop1_pop2/sfc_requirement_one_service/2021-06-30_18-39-53_seed9834/monitor.csv'

# %%
trained_400_octagon_drop_request = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_octagon_15_cap_pop1_pop2_ingress_diff_cap/tue_abc_one_service/trace_config_100_sim_duration_pop1_pop2/sfc_requirement_one_service/2021-06-30_18-39-53_seed9834/test-2021-06-30_18-39-53_seed9834/run_flows.csv'
trained_400_octagon_total_request = '/home/dat/git_folder_edge_4/realVNF/drl_vnf_project/results/sample_agent_100_DDPG_Baseline_one_service_flow_objective/tue_network_octagon_15_cap_pop1_pop2_ingress_diff_cap/tue_abc_one_service/trace_config_100_sim_duration_pop1_pop2/sfc_requirement_one_service/2021-06-30_18-39-53_seed9834/test-2021-06-30_18-39-53_seed9834/run_flows.csv'
balance_octagon_drop_request = '/home/dat/git_folder_edge_4/realVNF/baseline-algorithms/results/tue_network_octagon_15_cap_pop1_pop2_ingress_diff_cap/tue_abc_one_service/trace_config_100_sim_duration_pop1_pop2/2021-06-30_14-01-27_seed9058-balance/run_flows.csv'
balance_octagon_total_request = '/home/dat/git_folder_edge_4/realVNF/baseline-algorithms/results/tue_network_octagon_15_cap_pop1_pop2_ingress_diff_cap/tue_abc_one_service/trace_config_100_sim_duration_pop1_pop2/2021-06-30_14-01-27_seed9058-balance/run_flows.csv'
random_octagon_drop_request = '/home/dat/git_folder_edge_4/realVNF/baseline-algorithms/results/tue_network_octagon_15_cap_pop1_pop2_ingress_diff_cap/tue_abc_one_service/trace_config_100_sim_duration_pop1_pop2/2021-06-30_13-50-39_seed669-random/run_flows.csv'
random_octagon_total_request = '/home/dat/git_folder_edge_4/realVNF/baseline-algorithms/results/tue_network_octagon_15_cap_pop1_pop2_ingress_diff_cap/tue_abc_one_service/trace_config_100_sim_duration_pop1_pop2/2021-06-30_13-50-39_seed669-random/run_flows.csv'
shortest_octagon_drop_request = '/home/dat/git_folder_edge_4/realVNF/baseline-algorithms/results/tue_network_octagon_15_cap_pop1_pop2_ingress_diff_cap/tue_abc_one_service/trace_config_100_sim_duration_pop1_pop2/2021-06-30_13-49-02_seed5473-shortest_path/run_flows.csv'
shortest_octagon_total_request = '/home/dat/git_folder_edge_4/realVNF/baseline-algorithms/results/tue_network_octagon_15_cap_pop1_pop2_ingress_diff_cap/tue_abc_one_service/trace_config_100_sim_duration_pop1_pop2/2021-06-30_13-49-02_seed5473-shortest_path/run_flows.csv'

# %% [markdown]
# ### Functions for processing

# %% [markdown]
# To read to list

# %%
def read_csv_to_list(file_path, index_start_reading, colum_number):
    return_array = list()
    with open(file_path, newline='') as csvfile:
        spamreader = csv.reader(csvfile, delimiter=',', quotechar='|')
        for index, row in enumerate(spamreader):
            if index >= index_start_reading:
                return_array.append(float(row[colum_number]))
    return return_array

# %% [markdown]
# Calculate drop/succ rate

# %%
def calculate_drop_succ_rate(drop_arr, succ_arr):
    rate_arr = [drop_arr[i]/(drop_arr[i] + succ_arr[i]) for i in range(len(drop_arr))]
    return rate_arr

# %%
def calculate_drop_total_rate(drop_arr, total_arr):
    rate_arr = [drop_arr[i]/total_arr[i] for i in range(len(drop_arr))]
    return rate_arr

# %% [markdown]
# Filter for abnormal value

# %%
def filter_abnormal_values(array, value):
    return [i for i in array if i < value]

# %% [markdown]
# Ingress normalize

# %%
def ingress_traffic_calculation(ingress_arr):
    return [i*500 for i in ingress_arr]

# %% [markdown]
# ### Read files to variables

# %%
run_reward = list()
drop_request = list()
norm_ingress_traffic = list()
latency = list()
succ_request = list()
total_request = list()
drop_succ_rate = list()
runtime = list()
agent_time = list()
runtime_filtered = list()
agent_time_filtered = list()
ingress_traffic = list()

algos = ['trained_400', 'random', 'shortest', 'balance']
topology = "triangle"
reward_sim = read_csv_to_list(eval(f"{topology}_reward_file_path"), 2, 0)
for ind, algo in enumerate(algos):
    drop_request.append(read_csv_to_list(eval(f"{algo}_{topology}_drop_request"), 1, 3))
    total_request.append(read_csv_to_list(eval(f"{algo}_{topology}_total_request"), 1, 4))
    drop_succ_rate.append(calculate_drop_total_rate(eval(f"drop_request[{ind}]"), eval(f"total_request[{ind}]")))

# %%
trained_200_hexagon_reward_sim = read_csv_to_list(trained_200_hexagon_reward_file_path, 2, 0)
trained_400_hexagon_reward_sim = read_csv_to_list(trained_400_hexagon_reward_file_path, 2, 0)
trained_200_triangle_reward_sim = read_csv_to_list(trained_200_triange_reward_file_path, 2, 0)
trained_400_triangle_reward_sim = read_csv_to_list(trained_400_triange_reward_file_path, 2, 0)
trained_400_octagon_reward_sim = read_csv_to_list(trained_400_octagon_reward_file_path, 2, 0)

# %% [markdown]
# ### Draw latency graph through time after each case

# %%
trained_200_hexagon_reward_sim.pop()
trained_400_hexagon_reward_sim.pop()
trained_200_triangle_reward_sim.pop()
trained_400_triangle_reward_sim.pop()
trained_400_octagon_reward_sim.pop()
# Out:
# 29.579558

# %%
# trained_200_reward_sim.pop()
# trained_400_reward_sim.pop()
# plt.plot(trained_200_hexagon_reward_sim, label="200 hexagon")
plt.plot(trained_400_hexagon_reward_sim, label="hexagon")
# plt.plot(trained_200_triangle_reward_sim, label="200 triangle")
plt.plot(trained_400_triangle_reward_sim, label="triangle")
plt.plot(trained_400_octagon_reward_sim, label="octagon")
plt.title("Reward of RL models in different topology")
plt.xlabel("Trained episodes")
plt.ylabel("Reward")
plt.legend()
plt.show()

# %% [markdown]
# ### Algoprithm compare

# %%
x_range = [i * 15 for i in range(len(drop_succ_rate[0]))]

for index, algo in enumerate(algos):
    plt.plot(x_range, drop_succ_rate[index], label=f'{algo}')

plt.title("Drop request rate in hexagon topology")
plt.xlabel("Time (minute)")
plt.ylabel("Drop request rate")
plt.legend()
plt.show()
